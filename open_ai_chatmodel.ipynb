# %%
# %pip install -Uq langchain-openai dotenv
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    model = "gpt-5-mini"
)
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[6], line 3
#       1 from langchain_openai import ChatOpenAI
# ----> 3 llm = ChatOpenAI(
#       4     model = "gpt-5-mini"
#       5 )
#
# File c:\Users\User\Desktop\.venv\Lib\site-packages\langchain_core\load\serializable.py:118, in Serializable.__init__(self, *args, **kwargs)
#     116 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     117     """"""  # noqa: D419  # Intentional blank docstring
# --> 118     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File c:\Users\User\Desktop\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1090, in BaseChatOpenAI.validate_environment(self)
#    1080         self.http_async_client = httpx.AsyncClient(
#    1081             proxy=self.openai_proxy, verify=global_ssl_context
#    1082         )
#    1083     async_specific = {
# ...

# %%
result = llm.invoke("대전은 어떤 곳이니?")
result.pretty_print()
